# %%
#1.Find the error in the following Python code:
import math
print(math.sqrt(16)) #case sensitive
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function(x):
    x += 5
    print(x)

x = 10
my_function(x) #argument should be mentioned to the function while calling as well as in the definition
# Out:
# 15

# %%
#3.x = 5
if x == 10: #it should be conditional statement instead of assignment operator.
    print("x is 10")
# Out:
# x is 10

# %%
#4.
numbers = [5, 3, 8, 2]
numbers.sort()# only sorting of numbers will be done here
print(numbers) # should print the sorted numbers. by default it is ascending order.
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    return n * n #should return the value from the function to print

print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] == 5 # tuple in python is immutable.so value will not be changed
# Out:
# False

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))# mentioned arguments should be passed
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:# conditional operator should be == instead of is
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1,-1):
    print(i,end = ' ')
# Out:
# 5 4 3 2

# %%
#10.
student = {name: "John", age: 20}
print(student[name])#varaibale name should not be inside the quotes.
# Out:
# John
