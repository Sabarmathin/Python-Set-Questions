# %%
#1.Find the error in the following Python code:

for i in range(5) #: is missing
    print(i)
# Out:
#   Cell In[10], line 3
#     for i in range(5) #: is missing
#                       ^
# SyntaxError: expected ':'

# %%
#correct code
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)
# will get error. cannot cancatenate integer and string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       3 a = 10
#       4 b = "5"
# ----> 5 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#correct code convert string to int.
a = 10
b = "5"
print(a + int(b))
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b)#:is missing
    return a + b

# %%
#correct code
def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers[4])
#will give error there is no element for index 4 in the list. Indexes are [0],[1],[2],[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 4
#       1 #4.Identify the bug in the following Python code:
#       3 numbers = [1, 2, 3, 4]
# ----> 4 print(numbers[4])
#
# IndexError: list index out of range

# %%
#to access 4th element
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!" #no brackets
# Out:
#   Cell In[8], line 2
#     print "Hello, World!" #no brackets
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
#correct code
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0
#number cannot be divisible by 0. it should be other than zero.

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)
#there should be comma(,) instead of + before the variable value substitution.
# or integer and string cannot be concatenated....

# %%
#correct code
name = "Alice"
age = 25
print("Name: " , name + ", Age: " , age)
# Out:
# Name:  Alice, Age:  25

# %%
#correct code
name = "Alice"
age = 25
print("Name: " , name + ", Age: " , str(age))
# Out:
# Name:  Alice, Age:  25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#correct code
for i in range(10, 1, -1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")
#it should be if x==5. not assignment operatro conditional operator should be used

# %%
#correct code
x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

#: is missing

# %%
#correct code
def greet(name):
    print("Hello, " + name)
